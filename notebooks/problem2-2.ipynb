# %%
import sys 
sys.path.append('..')
from src.models.network_generator import SmallWorldNetwork, LatticeNetwork, PartialLatticeNetwork, RandomGraphNetwork 
from src.models.analyzer import NetworkAnalyzer

# %%
# initialize network generator
generator = SmallWorldNetwork(100, 4, 0.5)
# initialize analyzer
analyzer = NetworkAnalyzer()

G = generator.generate()
L, C = analyzer.calculate_metrics(G)
print(f"L={L:.3f}, C{C:.3f}")

# analyze propaties according to p-value
p_values, L_values, C_values = analyzer.analyze_propaties(generator, num_points=300)
analyzer.plot_propaties(p_values, L_values, C_values)
# Out:
# L=3.516, C0.052

# %%
# initialize network generator
generator = SmallWorldNetwork(100, 4, 0.5)
# generate graph
G = generator.generate()

# draw small-small-world network
generator.draw(G)

# %%
# initialize network generator
generator = LatticeNetwork(20, 20)

# generate lattice graph
G = generator.generate()

# draw a lattice graph
generator.draw(G)

# %%
# initialize network generator
generator = PartialLatticeNetwork(20, 20, 100)

# generate graph
G = generator.generate()

# draw a partial lattice network
generator.draw(G)

# %%
# random graph network

# initalize network generator
generator = RandomGraphNetwork(n_nodes=20, p_wiring=1)

# generate a random graph
G = generator.generate()

# draw a random graph
generator.draw(G)
