# %%
import sys 
sys.path.append('..')
from src.models.network import SmallWorldNetwork

# %%
G = SmallWorldNetwork(100, 4, 0.1)
p_values, C_values, L_values = G.analyze_propaties(num_points=300)
G.plot_propaties(p_values, C_values, L_values)

# %%
import numpy as np
from icecream import ic
a = np.logspace(0, 1, num=10, base=10)
ic(a)
# Out:
# ic| a: array([ 1.        ,  1.29154967,  1.66810054,  2.15443469,  2.7825594 ,
#                3.59381366,  4.64158883,  5.9948425 ,  7.74263683, 10.        ])
# array([ 1.        ,  1.29154967,  1.66810054,  2.15443469,  2.7825594 ,
#         3.59381366,  4.64158883,  5.9948425 ,  7.74263683, 10.        ])
